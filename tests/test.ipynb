# %%
from custom.bpe_counter import read_tokens, BPECounter

# %%
input_path = "/root/assignment1-basics/data/TinyStoriesV2-GPT4-valid.txt"
tokens = read_tokens(input_path)

# %%
tokens
# Out:
# ['u',
#  ' don',
#  "'t",
#  ' have',
#  ' to',
#  ' be',
#  ' scared',
#  ' of',
#  ' the',
#  ' loud',
#  ' dog',
#  ',',
#  ' I',
#  "'ll",
#  ' protect',
#  ' you',
#  '".',
#  ' The',
#  ' mole',
#  ' felt',
#  ' so',
#  ' safe',
#  ' with',
#  ' the',
#  ' little',
#  ' girl',
#  '.',
#  ' She',
#  ' was',
#  ' very',
#  ' kind',
#  ' and',
#  ' the',
#  ' mole',
#  ' soon',
#  ' came',
#  ' to',
#  ' trust',
#  ' her',
#  '.',
#  ' He',
#  ' leaned',
#  ' against',
#  ' her',
#  ' and',
#  ' she',
#  ' kept',
#  ' him',
#  ' safe',
#  '.',
#  ' The',
#  ' mole',
#  ' had',
#  ' found',
#  ' his',
#  ' best',
#  ' friend',
#  '.',
#  'Once',
#  ' upon',
#  ' a',
#  ' time',
#  ',',
#  ' in',
#  ' a',
#  ' warm',
#  ' and',
#  ' sunny',
#  ' place',
#  ',',
#  ' there',
#  ' was',
#  ' a',
#  ' big',
#  ' pit',
#  '.',
#  ' A',
#  ' little',
#  ' boy',
#  ' named',
#  ' Tom',
#  ' liked',
#  ' to',
#  ' play',
#  ' near',
#  ' the',
#  ' pit',
#  '.',
#  ' One',
#  ' day',
# ...
